# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/mlbootcamp5_train.csv', sep = ';')
df.head(10)
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
# 5   8  21914       1     151    67.0    120     80            2     2      0
# 6   9  22113       1     157    93.0    130     80            3     1      0
# 7  12  22584       2     178    95.0    130     90            3     3      0
# 8  13  17668       1     158    71.0    110     70            1     1      0
# 9  14  19834       1     164    68.0    110     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# ...

# %%
df.shape
# Out:
# (70000, 13)

# %%
df_uniques = pd.melt(frame=df, value_vars=['gender','cholesterol', 
                                           'gluc', 'smoke', 'alco', 
                                           'active', 'cardio'])

# %%
df_uniques = pd.DataFrame(df_uniques.groupby(['variable', 
                                              'value'])['value'].count()) \
    .sort_index(level=[0, 1]) \
    .rename(columns={'value': 'count'}) \
    .reset_index()

# %%
sns.factorplot(x='variable', y='count', hue='value', 
               data=df_uniques, kind='bar', size=12);
# Out:
# C:\Users\valer\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\valer\Anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df_uniques = pd.melt(frame=df, value_vars=['gender','cholesterol', 
                                           'gluc', 'smoke', 'alco', 
                                           'active'], 
                     id_vars=['cardio'])

# %%
df_uniques = pd.DataFrame(df_uniques.groupby(['variable', 'value', 
                                              'cardio'])['value'].count()) \
    .sort_index(level=[0, 1]) \
    .rename(columns={'value': 'count'}) \
    .reset_index()

# %%
sns.factorplot(x='variable', y='count', hue='value', 
               col='cardio', data=df_uniques, kind='bar', size=8);

# %%
for c in df.columns:
    n = df[c].nunique()
    print(c)
    if n <= 3:
        print(n, sorted(df[c].value_counts().to_dict().items()))
    else:
        print(n)
    print(10 * '-')
# Out:
# id
# 70000
# ----------
# age
# 8076
# ----------
# gender
# 2 [(1, 45530), (2, 24470)]
# ----------
# height
# 109
# ----------
# weight
# 287
# ----------
# ap_hi
# 153
# ----------
# ap_lo
# 157
# ----------
# cholesterol
# 3 [(1, 52385), (2, 9549), (3, 8066)]
# ----------
# gluc
# 3 [(1, 59479), (2, 5190), (3, 5331)]
# ----------
# smoke
# 2 [(0, 63831), (1, 6169)]
# ----------
# alco
# 2 [(0, 66236), (1, 3764)]
# ----------
# active
# 2 [(0, 13739), (1, 56261)]
# ----------
# cardio
# 2 [(0, 35021), (1, 34979)]
# ----------

# %%
df.head(6)
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
# 5   8  21914       1     151    67.0    120     80            2     2      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0
# 5     0       0       0

# %%
df['gender'].value_counts()
# Out:
# 1    45530
# 2    24470
# Name: gender, dtype: int64

# %%
df.groupby('gender')['height'].mean()
# Out:
# gender
# 1    161.355612
# 2    169.947895
# Name: height, dtype: float64

# %%
df.groupby('gender')['weight'].mean()
# Out:
# gender
# 1    72.565605
# 2    77.257307
# Name: weight, dtype: float64

# %%
sns.countplot(x ='gender', data = df, hue = 'alco');

# %%
pd.crosstab(df['gender'], df['alco'])
# Out:
# alco        0     1
# gender
# 1       44369  1161
# 2       21867  2603

# %%
df.groupby('gender')['alco'].mean()
# Out:
# gender
# 1    0.025500
# 2    0.106375
# Name: alco, dtype: float64

# %%
pd.crosstab(df['gender'], df['smoke'])
# Out:
# smoke       0     1
# gender
# 1       44717   813
# 2       19114  5356

# %%
df.groupby('gender')['smoke'].mean()
# Out:
# gender
# 1    0.017856
# 2    0.218880
# Name: smoke, dtype: float64

# %%
round((0.21880 - 0.017856) *100)
# Out:
# 20

# %%
df.groupby('smoke')['age'].median()
# Out:
# smoke
# 0    19722
# 1    19125
# Name: age, dtype: int64

# %%
round((19722 - 19125)/30)
# Out:
# 20

# %%
df['age_years'] = (df['age']/365.25).round().astype('int')

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio  age_years
# 0     0       1       0         50
# 1     0       1       1         55
# 2     0       0       1         52
# 3     0       1       1         48
# 4     0       0       0         48

# %%
df['age_years'].max()
# Out:
# 65

# %%
smoking_old_men = df[(df['age_years'] >= 60) & (df['age_years'] <= 64) & 
                    (df['gender'] == 2) & (df['smoke'] == 1)]
smoking_old_men.head()
# Out:
#       id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 19    29  21755       2     162    56.0    120     70            1     1
# 38    52  23388       2     162    72.0    130     80            1     1
# 67    90  22099       2     171    97.0    150    100            3     1
# 177  240  21848       2     170    69.0    120     80            1     1
# 182  248  22671       2     174    74.0    130     80            3     1
#
#      smoke  alco  active  cardio  age_years
# 19       1     0       1       0         60
# 38       1     0       1       1         64
# 67       1     0       1       1         61
# 177      1     1       1       0         60
# 182      1     0       1       1         62

# %%
smoking_old_men[(smoking_old_men['cholesterol'] == 1) &
               (smoking_old_men['ap_hi'] < 120)]['cardio'].mean()
# Out:
# 0.2631578947368421

# %%
smoking_old_men[(smoking_old_men['cholesterol'] == 3) &
               (smoking_old_men['ap_hi'] >= 160) &
               (smoking_old_men['ap_hi'] < 180)]['cardio'].mean()
# Out:
# 0.8636363636363636

# %%
df['BMI'] = df['weight'] / (df['height']/100)**2
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio  age_years        BMI
# 0     0       1       0         50  21.967120
# 1     0       1       1         55  34.927679
# 2     0       0       1         52  23.507805
# 3     0       1       1         48  28.710479
# 4     0       0       0         48  23.011177

# %%
df['BMI'].median() # NO
# Out:
# 26.374068120774975

# %%
df.groupby(df['gender'])['BMI'].median() # YES
# Out:
# gender
# 1    26.709402
# 2    25.910684
# Name: BMI, dtype: float64

# %%
df.groupby(['gender', 'alco', 'cardio'])['BMI'].mean().to_frame()
# Out:
#                           BMI
# gender alco cardio
# 1      0    0       26.845407
#             1       29.052771
#        1    0       28.671457
#             1       30.812347
# 2      0    0       25.872638
#             1       27.522450
#        1    0       26.097220
#             1       28.226569

# %%
filtered_df = df[(df['ap_lo'] <= df['ap_hi']) & 
                 (df['height'] >= df['height'].quantile(0.025)) &
                 (df['height'] <= df['height'].quantile(0.975)) &
                 (df['weight'] >= df['weight'].quantile(0.025)) & 
                 (df['weight'] <= df['weight'].quantile(0.975))]

# %%
(1 - filtered_df.shape[0] / df.shape[0])*100
# Out:
# 9.630000000000006

# %%
sns.set()
sns.set_context(
    "notebook", 
    font_scale=1.5,       
    rc={ 
        "figure.figsize": (11, 8), 
        "axes.titlesize": 18 
    }
)
sns.heatmap(df.corr());

# %%
corr = df.corr(method='pearson')

# Create a mask to hide the upper triangle of the correlation matrix (which is symmetric)

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(12, 9))

sns.heatmap(corr, mask=mask, vmax=1, center=0, annot=True, fmt='.1f',
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
df_melt = pd.melt(frame=df, value_vars=['height'], id_vars=['gender'])

plt.figure(figsize=(12, 10))
ax = sns.violinplot(
    x='variable', 
    y='value', 
    hue='gender', 
    palette="muted", 
    split=True, 
    data=df_melt, 
    scale='count',
    scale_hue=False
)

# %%
corr = df.corr(method='spearman')

# Create a mask to hide the upper triangle of the correlation matrix (which is symmetric)

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(12, 9))

sns.heatmap(corr, mask=mask, vmax=1, center=0, annot=True, fmt='.1f',
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
sns.violinplot(x = 'height', data = df, hue = 'gender');

# %%
sns.countplot(x="age_years", hue='cardio', data=df);
plt.rcParams['figure.figsize'] = (8,6)
